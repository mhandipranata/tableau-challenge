# %%
import pandas as pd
import glob

# %%
# Load and read the citibike history csv for the last 6 months
citibike_oct19 = pd.read_csv("citibike_history_csv/JC-201910-citibike-tripdata.csv")
citibike_nov19 = pd.read_csv("citibike_history_csv/JC-201911-citibike-tripdata.csv")
citibike_dec19 = pd.read_csv("citibike_history_csv/JC-201912-citibike-tripdata.csv")
citibike_jan20 = pd.read_csv("citibike_history_csv/JC-202001-citibike-tripdata.csv")
citibike_feb20 = pd.read_csv("citibike_history_csv/JC-202002-citibike-tripdata.csv")
citibike_mar20 = pd.read_csv("citibike_history_csv/JC-202003-citibike-tripdata.csv")

# %%
print(len(citibike_oct19))
print(len(citibike_nov19))
print(len(citibike_dec19))
print(len(citibike_jan20))
print(len(citibike_feb20))
print(len(citibike_mar20))
# Out:
# 42253
# 30797
# 19728
# 26020
# 22962
# 17719

# %%
path = r'/Users/michellehandipranata/Desktop/tableau-challenge/citibike_history_csv'

all_files = glob.glob(path + "/*.csv")

list_df = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    list_df.append(df)

consolidated_csv = pd.concat(li, axis=0, ignore_index=True)
consolidated_csv
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                841  2020-02-01 00:02:13.7650  2020-02-01 00:16:15.4720
# 1                206  2020-02-01 00:16:11.3850  2020-02-01 00:19:37.4460
# 2                859  2020-02-01 00:23:22.1090  2020-02-01 00:37:41.5060
# 3                693  2020-02-01 00:25:14.5170  2020-02-01 00:36:48.0280
# 4               1473  2020-02-01 00:32:30.5050  2020-02-01 00:57:04.3740
# ...              ...                       ...                       ...
# 159474           544  2020-01-31 23:29:29.3910  2020-01-31 23:38:33.6910
# 159475           122  2020-01-31 23:30:59.3670  2020-01-31 23:33:01.6870
# 159476           201  2020-01-31 23:42:34.8460  2020-01-31 23:45:55.8780
# 159477           300  2020-01-31 23:45:00.6800  2020-01-31 23:50:00.8740
# 159478           721  2020-01-31 23:48:35.1700  2020-02-01 00:00:36.4060
#
#         start station id          start station name  start station latitude  \
# ...

# %%
consolidated_csv["gender"].unique().dtype
# Out:
# dtype('int64')

# %%
consolidated_csv["gender"].replace({0: "Unknown", 1: "Male", 2: "Female"}, inplace=True)
consolidated_csv
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                841  2020-02-01 00:02:13.7650  2020-02-01 00:16:15.4720
# 1                206  2020-02-01 00:16:11.3850  2020-02-01 00:19:37.4460
# 2                859  2020-02-01 00:23:22.1090  2020-02-01 00:37:41.5060
# 3                693  2020-02-01 00:25:14.5170  2020-02-01 00:36:48.0280
# 4               1473  2020-02-01 00:32:30.5050  2020-02-01 00:57:04.3740
# ...              ...                       ...                       ...
# 159474           544  2020-01-31 23:29:29.3910  2020-01-31 23:38:33.6910
# 159475           122  2020-01-31 23:30:59.3670  2020-01-31 23:33:01.6870
# 159476           201  2020-01-31 23:42:34.8460  2020-01-31 23:45:55.8780
# 159477           300  2020-01-31 23:45:00.6800  2020-01-31 23:50:00.8740
# 159478           721  2020-01-31 23:48:35.1700  2020-02-01 00:00:36.4060
#
#         start station id          start station name  start station latitude  \
# ...

# %%
consolidated_csv["starttime"].dtype
# Out:
# dtype('O')

# %%
consolidated_csv["Start Date"] = pd.to_datetime(consolidated_csv["starttime"]).dt.date
consolidated_csv["Start Time"] = pd.to_datetime(consolidated_csv["starttime"]).dt.time
consolidated_csv["Stop Date"] = pd.to_datetime(consolidated_csv["stoptime"]).dt.date
consolidated_csv["Stop Time"] = pd.to_datetime(consolidated_csv["stoptime"]).dt.time
consolidated_csv
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                841  2020-02-01 00:02:13.7650  2020-02-01 00:16:15.4720
# 1                206  2020-02-01 00:16:11.3850  2020-02-01 00:19:37.4460
# 2                859  2020-02-01 00:23:22.1090  2020-02-01 00:37:41.5060
# 3                693  2020-02-01 00:25:14.5170  2020-02-01 00:36:48.0280
# 4               1473  2020-02-01 00:32:30.5050  2020-02-01 00:57:04.3740
# ...              ...                       ...                       ...
# 159474           544  2020-01-31 23:29:29.3910  2020-01-31 23:38:33.6910
# 159475           122  2020-01-31 23:30:59.3670  2020-01-31 23:33:01.6870
# 159476           201  2020-01-31 23:42:34.8460  2020-01-31 23:45:55.8780
# 159477           300  2020-01-31 23:45:00.6800  2020-01-31 23:50:00.8740
# 159478           721  2020-01-31 23:48:35.1700  2020-02-01 00:00:36.4060
#
#         start station id          start station name  start station latitude  \
# ...

# %%
consolidated_csv.rename(columns = {
    "tripduration": "Trip Duration",
    "start station id": "Start Station ID",
    "start station name": "Start Station Name",
    "start station latitude": "Start Station Latitude",
    "start station longitude": "Start Station Longitude",
    "end station id": "End Station ID",
    "end station name": "End Station Name",
    "end station latitude": "End Station Latitude",
    "end station longitude": "End Station Longitude",
    "bikeid": "Bike ID",
    "usertype": "User Type",
    "birth year": "Birth Year",
    "gender": "Gender"
}, inplace = True)

consolidated_csv
# Out:
#         Trip Duration                 starttime                  stoptime  \
# 0                 841  2020-02-01 00:02:13.7650  2020-02-01 00:16:15.4720
# 1                 206  2020-02-01 00:16:11.3850  2020-02-01 00:19:37.4460
# 2                 859  2020-02-01 00:23:22.1090  2020-02-01 00:37:41.5060
# 3                 693  2020-02-01 00:25:14.5170  2020-02-01 00:36:48.0280
# 4                1473  2020-02-01 00:32:30.5050  2020-02-01 00:57:04.3740
# ...               ...                       ...                       ...
# 159474            544  2020-01-31 23:29:29.3910  2020-01-31 23:38:33.6910
# 159475            122  2020-01-31 23:30:59.3670  2020-01-31 23:33:01.6870
# 159476            201  2020-01-31 23:42:34.8460  2020-01-31 23:45:55.8780
# 159477            300  2020-01-31 23:45:00.6800  2020-01-31 23:50:00.8740
# 159478            721  2020-01-31 23:48:35.1700  2020-02-01 00:00:36.4060
#
#         Start Station ID          Start Station Name  Start Station Latitude  \
# ...

# %%
list(consolidated_csv.columns)
# Out:
# ['Trip Duration',
#  'starttime',
#  'stoptime',
#  'Start Station ID',
#  'Start Station Name',
#  'Start Station Latitude',
#  'Start Station Longitude',
#  'End Station ID',
#  'End Station Name',
#  'End Station Latitude',
#  'End Station Longitude',
#  'Bike ID',
#  'User Type',
#  'Birth Year',
#  'Gender',
#  'Start Date',
#  'Start Time',
#  'Stop Date',
#  'Stop Time']

# %%
consolidated_csv_clean = consolidated_csv.loc[:, ['Trip Duration', 'Start Date', 'Start Time',
                                                  'Stop Date','Stop Time', 'Start Station ID',
                                                  'Start Station Name', 'Start Station Latitude',
                                                  'Start Station Longitude', 'End Station ID',
                                                  'End Station Name', 'End Station Latitude',
                                                  'End Station Longitude', 'Bike ID', 'User Type',
                                                  'Birth Year', 'Gender']].copy()
consolidated_csv_clean
# Out:
#         Trip Duration  Start Date       Start Time   Stop Date  \
# 0                 841  2020-02-01  00:02:13.765000  2020-02-01
# 1                 206  2020-02-01  00:16:11.385000  2020-02-01
# 2                 859  2020-02-01  00:23:22.109000  2020-02-01
# 3                 693  2020-02-01  00:25:14.517000  2020-02-01
# 4                1473  2020-02-01  00:32:30.505000  2020-02-01
# ...               ...         ...              ...         ...
# 159474            544  2020-01-31  23:29:29.391000  2020-01-31
# 159475            122  2020-01-31  23:30:59.367000  2020-01-31
# 159476            201  2020-01-31  23:42:34.846000  2020-01-31
# 159477            300  2020-01-31  23:45:00.680000  2020-01-31
# 159478            721  2020-01-31  23:48:35.170000  2020-02-01
#
#               Stop Time  Start Station ID          Start Station Name  \
# 0       00:16:15.472000              3199                Newport Pkwy
# ...

# %%
consolidated_csv_clean.to_csv("citibike_consolidated_data.csv", index=False)
